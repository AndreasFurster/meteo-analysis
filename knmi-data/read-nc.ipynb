# %%
import netCDF4 as nc

fn = 'KMDS__OPER_P___10M_OBS_L2_202203070840.nc'
ds = nc.Dataset(fn)

print(ds)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     featureType: timeSeries
#     Conventions: CF-1.4
#     title: KMDS__OPER_P___10M_OBS_L2
#     institution: Royal Netherlands Meteorological Institute (KNMI)
#     source: Royal Netherlands Meteorological Institute (KNMI)
#     history: File created from KMDS ASCII file.
#     references: http://data.knmi.nl
#     comment: Please note: no data has been found for the following variables: ts1, ts2
#     dimensions(sizes): station(46), time(1)
# ...

# %%
for var in ds.variables.values():
  print("var:", var.name)

  # Print all attributes
  for attr in var.ncattrs():
    print('{:20s} = {}'.format(attr, getattr(var, attr)))

  print("")
# Out:
# var: station
# long_name            = Station id
# cf_role              = timeseries_id
#
# var: time
# long_name            = time of measurement
# standard_name        = time
# units                = seconds since 1950-01-01 00:00:00
#
# var: stationname
# long_name            = Station name
#
# var: lat
# long_name            = station  latitude
# standard_name        = latitude
# units                = degrees_north
#
# var: lon
# long_name            = station longitude
# standard_name        = longitude
# units                = degrees_east
#
# var: height
# long_name            = Station height
# standard_name        = height
# units                = m
#
# var: dd
# _FillValue           = -9999.0
# standard_name        = wind_from_direction
# units                = degree
# long_name            = Wind Direction 10 Min Average
#
# var: ff
# _FillValue           = -9999.0
# standard_name        = wind_speed
# units                = m s-1
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt

# ta = air temperature
ta = ds.variables['ta'][:]
station = ds.variables['stationname'][:]

# print(ta[:])

# print(ds.dimensions)

# for d in ds.dimensions.values():
#   print(d)

# for var in ds.variables.values():
#   print(var)



temperatures = np.array([item[0] for item in ta])



px = 1 / plt.rcParams['figure.dpi']  # pixel in inches
plt.subplots(figsize=(1100 * px, 600 * px))

plt.bar(station, temperatures) 
plt.xticks(rotation='vertical')


plt.show()
# Out:
# C:\Users\andreas\AppData\Local\Temp\ipykernel_19828\4091567735.py:20: UserWarning: Warning: converting a masked element to nan.
#   temperatures = np.array([item[0] for item in ta])
